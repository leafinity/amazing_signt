# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
import tensorflow as tf

# %%
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
import tensorflow as tf
from IPython import display
from utils import ideal_crop 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from ast import literal_eval
from tqdm import tqdm_notebook
import pathlib
import helper
import tensorflow.keras as keras
from sklearn.utils import shuffle
from glob import glob
import cv2
from tensorflow.keras.models import model_from_json
# from layer import *

# %%
def crop_resize_image(image):
    std_height, std_width = 68, 120
    image = np.array(image).astype('float32')/255.
    height, width = image.shape[:2]
    if (height/std_height)<=(width/std_width):
        r = height/std_height
    else:
        r = width/std_width
    new_height, new_width = int(std_height*r), int(std_width*r)
    h_center, w_center = height//2, width//2
        
    image = image[int(h_center-(new_height//2)):int(h_center-(new_height//2)+new_height), 
                  int(w_center-(new_width//2)):int(w_center-(new_width//2)+new_width)]
    return image

# %%
# datagen = keras.preprocessing.image.ImageDataGenerator(featurewise_center=False, 
#                                                        samplewise_center=False, 
#                                                        featurewise_std_normalization=False, 
#                                                        samplewise_std_normalization=False, 
#                                                        zca_whitening=False, 
#                                                        zca_epsilon=1e-06, 
#                                                        rotation_range=0, 
#                                                        width_shift_range=0.0, 
#                                                        height_shift_range=0.0, 
#                                                        brightness_range=None, 
#                                                        shear_range=0.0, 
#                                                        zoom_range=0.0, 
#                                                        channel_shift_range=0.0, 
#                                                        fill_mode='nearest', 
#                                                        cval=0.0,
#                                                        horizontal_flip=False, 
#                                                        vertical_flip=False, 
#                                                        rescale=None, 
#                                                        preprocessing_function=crop_resize_image, 
#                                                        data_format=None, 
#                                                        validation_split=0.0, 
#                                                        dtype=None)

# %%
# def read_imgs(root_path):

# %%
imgs_list = glob('/home/jovyan/ta-hsi-datacenter/resize_68_120/mountain/*.jpg')
imgs = []
for i in tqdm_notebook(imgs_list):
    img = cv2.imread(i)[:,:,::-1]
    img = crop_resize_image(img)
    img = np.array(img, dtype=np.float16)
    imgs.append(img)
imgs = np.array(imgs, dtype=np.float16)
# Out:
# HBox(children=(IntProgress(value=0, max=8179), HTML(value='')))

# %%
# '../../ta-hsi-datacenter/output_results/input_imgs/resize_272_480/',
#               '../../ta-hsi-datacenter/output_results/input_imgs/resize_136_240/',
#                '../../ta-hsi-datacenter/output_results/input_imgs/resize_68_120/',
#                '../../ta-hsi-datacenter/output_results/input_imgs/resize_34_60/',
#                '../../ta-hsi-datacenter/output_results/input_imgs/resize_17_30/'

# %%
list_name = ['resize_272_480','resize_136_240','resize_68_120','resize_34_60','resize_17_30']
imgs_list_272_480 = glob('../../ta-hsi-datacenter/output_results/input_imgs/resize_272_480/*.jpg')
imgs_list_136_240 = glob('../../ta-hsi-datacenter/output_results/input_imgs/resize_136_240/*.jpg')
imgs_list_68_120 = glob('../../ta-hsi-datacenter/output_results/input_imgs/resize_68_120/*.jpg')
imgs_list_34_60 = glob('../../ta-hsi-datacenter/output_results/input_imgs/resize_34_60/*.jpg')
imgs_list_17_30 = glob('../../ta-hsi-datacenter/output_results/input_imgs/resize_17_30/*.jpg')
imgs_list = [imgs_list_272_480,imgs_list_136_240,imgs_list_68_120,imgs_list_34_60,imgs_list_17_30]








imgs_272_480_arr = []
for i in tqdm_notebook(imgs_list_272_480):
    img = cv2.imread(i)[:,:,::-1]
    img = crop_resize_image(img)
    img = np.array(img, dtype=np.float16)
    imgs_272_480_arr.append(img)
imgs_272_480_arr = np.array(imgs_272_480_arr, dtype=np.float16)


# imgs_136_240_arr = []
# for i in tqdm_notebook(imgs_list_136_240):
#     img = cv2.imread(i)[:,:,::-1]
#     img = crop_resize_image(img)
#     img = np.array(img, dtype=np.float16)
#     imgs_136_240_arr.append(img)
# imgs_136_240_arr = np.array(imgs_136_240_arr, dtype=np.float16)


imgs_68_120_arr = []
for i in tqdm_notebook(imgs_list_68_120):
    img = cv2.imread(i)[:,:,::-1]
    img = crop_resize_image(img)
    img = np.array(img, dtype=np.float16)
    imgs_68_120_arr.append(img)
imgs_68_120_arr = np.array(imgs_68_120_arr, dtype=np.float16)


# imgs_34_60_arr = []
# for i in tqdm_notebook(imgs_list_68_120):
#     img = cv2.imread(i)[:,:,::-1]
#     img = crop_resize_image(img)
#     img = np.array(img, dtype=np.float16)
#     imgs_34_60_arr.append(img)
# imgs_34_60_arr = np.array(imgs_34_60_arr, dtype=np.float16)


imgs_17_30_arr = []
for i in tqdm_notebook(imgs_list_17_30):
    img = cv2.imread(i)[:,:,::-1]
    img = crop_resize_image(img)
    img = np.array(img, dtype=np.float16)
    imgs_17_30_arr.append(img)
imgs_17_30_arr = np.array(imgs_17_30_arr, dtype=np.float16)


# imgs_arr = np.array(imgs_arr)
# Out:
# HBox(children=(IntProgress(value=0, max=9876), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=9876), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=9876), HTML(value='')))

# %%
imgs_arr = [imgs]
# imgs_arr = [imgs_17_30_arr,imgs_34_60_arr,imgs_68_120_arr,imgs_136_240_arr,imgs_272_480_arr]

# %%
# imgs[list_name[0]].dump('../../ta-hsi-datacenter/output_results/model/resize_272_480.npy')
# imgs[list_name[1]].dump('../../ta-hsi-datacenter/output_results/model/resize_136_240.npy')
# imgs[list_name[2]].dump('../../ta-hsi-datacenter/output_results/model/resize_68_120.npy')
# imgs[list_name[3]].dump('../../ta-hsi-datacenter/output_results/model/resize_34_60.npy')
# imgs[list_name[4]].dump('../../ta-hsi-datacenter/output_results/model/resize_17_30.npy')
# np.save('../../ta-hsi-datacenter/output_results/model/',imgs[list_name[0]])


### load
# imgs[list_name[0]].load('../../ta-hsi-datacenter/output_results/model/resize_272_480.npy')
# imgs[list_name[1]].load('../../ta-hsi-datacenter/output_results/model/resize_136_240.npy')
# imgs[list_name[2]].load('../../ta-hsi-datacenter/output_results/model/resize_68_120.npy')
# imgs[list_name[3]].load('../../ta-hsi-datacenter/output_results/model/resize_34_60.npy')
# imgs[list_name[4]].load('../../ta-hsi-datacenter/output_results/model/resize_17_30.npy')

# %%
# def residual_block(res_input,conv_dim):
#     x = layers.Conv2D(conv_dim, 3, strides=1, padding='same')(res_input)
#     x = layers.ReLU()(x)
#     x = layers.Conv2D(conv_dim, 3, strides=1, padding='same')(x)
#     x = layers.add([x, res_input])
#     x = layers.ReLU()(x)

#     return x

# %%
import tensorflow.keras.layers as layers

def build_generator(latent_dim, output_size):
    filter_num = [256, 128, 64 , 32]
    generator_input = keras.Input(shape=(latent_dim,))
    
    
    height, width = output_size
    
    x = layers.Dense(filter_num[0] * int(height//4) * int(width//4))(generator_input)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Reshape((int(height//4), int(width//4), filter_num[0]))(x) 
    
    #### 17*30*256
    x = layers.UpSampling2D(size=(2, 2))(x)
    x = layers.Conv2DTranspose(filter_num[0],(3,3),strides=(1,1),padding='same')(x)  
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Conv2DTranspose(filter_num[0],(3,3),strides=(1,1),padding='same' )(x)
    x = layers.LeakyReLU(0.2)(x)

    #### 34*60*128
           
#     x = residual_block(x,filter_num[0])
#     x = residual_block(x,filter_num[0])
#     x = layers.Conv2DTranspose(filter_num[1],(5,5),strides=(2,2),padding='same')(x)
    x = layers.UpSampling2D(size=(2, 2))(x)
    x = layers.Conv2DTranspose(filter_num[1],(3,3),strides=(1,1),padding='same')(x)
    x = layers.LeakyReLU(0.2)(x)   
    x = layers.Conv2DTranspose(filter_num[1],(3,3),strides=(1,1),padding='same')(x)
    x = layers.LeakyReLU(0.2)(x) 
    x = layers.Conv2DTranspose(3,(1,1),strides=(1,1),padding='same',activation='linear')(x)
    
    #### 34*60*128
    
#     x = residual_block(x,filter_num[1])
#     x = residual_block(x,filter_num[1])

#     x = layers.UpSampling2D(size=(2, 2))(x)    
#     x = layers.Conv2DTranspose(filter_num[2],(3,3),strides=(1,1),padding='same')(x)
#     x = layers.LeakyReLU(0.2)(x)
#     x = layers.Conv2DTranspose(filter_num[2],(3,3),strides=(1,1),padding='same')(x)
#     x = layers.LeakyReLU(0.2)(x)
#     x = layers.Conv2DTranspose(3,(1,1),strides=(1,1),padding='same',activation='linear')(x)
    
    #### 68*120*32
    
#     x = residual_block(x,filter_num[2])
#     x = residual_block(x,filter_num[2])
#     x = layers.Conv2DTranspose(filter_num[3],(5,5),strides=(2,2),padding='same')(x)
#     x = layers.Conv2DTranspose(filter_num[3],(5,5),strides=(1,1),padding='same')(x)
#     x = layers.LeakyReLU(0.2)(x)
    
    #### 136*240*16
    
#     x = residual_block(x,filter_num[3])
#     x = residual_block(x,filter_num[3])
#     x = layers.Conv2DTranspose(filter_num[3],(5,5),strides=(2,2),padding='same')(x)
#     x = layers.Conv2DTranspose(3,(5,5),strides=(1,1),padding='same',activation='tanh')(x)
    
    #### 272*480*3
    
    
    generator = keras.models.Model(generator_input,x)
    
    return keras.models.Model(generator_input,x)

# %%
G = build_generator(100, (68,120))
G.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense (Dense)                (None, 130560)            13186560
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 130560)            0
# _________________________________________________________________
# reshape (Reshape)            (None, 17, 30, 256)       0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 34, 60, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 34, 60, 256)       590080
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 34, 60, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 34, 60, 256)       590080
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 34, 60, 256)       0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 68, 120, 256)      0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 68, 120, 128)      295040
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 68, 120, 128)      0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 68, 120, 128)      147584
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 68, 120, 128)      0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 68, 120, 3)        387
# =================================================================
# Total params: 14,809,731
# Trainable params: 14,809,731
# Non-trainable params: 0
# _________________________________________________________________

# %%
# G.

# %%
#### Generator split group 
# G_split = [7,9,11,13,15]

# %%
def build_discriminator(input_size):
    height, width, channels = input_size
    filter_num = [128,256]
    
    discriminator_input = layers.Input(shape=(height, width, channels))
    
    x = layers.Conv2D(filter_num[0], 3, padding = 'same')(discriminator_input)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Conv2D(filter_num[0], 3, padding = 'same')(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Conv2D(filter_num[0], 3, padding = 'same')(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.AveragePooling2D()(x)
    
    #### 272*480*16
#     x = MinibatchStatConcatLayer(averaging='all', name='Dstat')(x)
#     x = add_minibatch_stddev_feat(x)
    x = layers.Conv2D(filter_num[1], 3, strides = 1, padding = 'same')(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Conv2D(filter_num[1], 4, strides = 1, padding = 'same')(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.AveragePooling2D()(x)
    
    #### 136*240*32
    
#     x = layers.Conv2D(filter_num[2], 4, strides = 2, padding = 'same')(x)
#     x = layers.ReLU()(x)
    
#     #### 68*120*64
    
#     x = layers.Conv2D(filter_num[3], 4, strides = 2, padding = 'same')(x)
#     x = layers.ReLU()(x)
    
#     #### 34*60*128
    
#     x = layers.Conv2D(3, 4, strides = 2, padding = 'same')(x)
#     x = layers.ReLU()(x)
    
    #### 17*30*3
    
#     x = layers.Conv2D(128, 4, strides = 2, padding = 'same')(x)
#     x = layers.ReLU()(x)
    
#     x = layers.Conv2D(256, 4, strides = 2, padding = 'same')(x)
#     x = layers.ReLU()(x)


    x = layers.Flatten()(x)

    x = layers.Dropout(0.4)(x)


    x = layers.Dense(1, activation='sigmoid')(x)

    discriminator = keras.models.Model(discriminator_input, x)
    return discriminator

# %%
# D_split = [3,5,7,9,14]

# %%
D = build_discriminator((68, 120,3))
D.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 68, 120, 3)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 68, 120, 128)      3584
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 68, 120, 128)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 68, 120, 128)      147584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 68, 120, 128)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 68, 120, 128)      147584
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 68, 120, 128)      0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 34, 60, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 60, 256)       295168
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 34, 60, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 34, 60, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 34, 60, 256)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 17, 30, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 130560)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 130560)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 130561
# =================================================================
# Total params: 1,773,313
# Trainable params: 1,773,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
def build_GAN(G, D):
    D.trainable = False
    gan_input = G.input
    gan_output = D(G(gan_input))
    gan = keras.models.Model(gan_input, gan_output)
    return gan

# %%
GAN = build_GAN(G, D)
GAN.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# model_1 (Model)              (None, 68, 120, 3)        14809731
# _________________________________________________________________
# model_2 (Model)              (None, 1)                 1773313
# =================================================================
# Total params: 16,583,044
# Trainable params: 14,809,731
# Non-trainable params: 1,773,313
# _________________________________________________________________

# %%
iterations = 10000
latent_dim = 200
height_1, width_1 = 68, 120
height_2, width_2 = 544, 960

G1 = build_generator(latent_dim, (height_1, width_1))
D1 = build_discriminator((height_1, width_1, 3))
optimizer = keras.optimizers.Adam(lr=0.0001, beta_1 = 0.5)
D1.compile(loss = 'binary_crossentropy', optimizer = optimizer)

GAN1 = build_GAN(G1, D1)
optimizer = keras.optimizers.Adam(lr = 0.0001, beta_1 = 0.5)
GAN1.compile(loss = 'binary_crossentropy', optimizer = optimizer)

# %%
G1_json = G1.to_json()
D1_json = D1.to_json()
GAN1_json = GAN1.to_json()

os.makedirs("../../ta-hsi-datacenter/output_results/model/resize_68_120/",exist_ok=True)

with open("../../ta-hsi-datacenter/output_results/model/resize_68_120/G1_68_120.json","w") as json_file:
    json_file.write(G1_json)
    
with open("../../ta-hsi-datacenter/output_results/model/resize_68_120/D1_68_120.json","w") as json_file:
    json_file.write(D1_json)
    
with open("../../ta-hsi-datacenter/output_results/model/resize_68_120/GAN1_68_120.json","w") as json_file:
    json_file.write(GAN1_json)

# %%
# import os
# from keras.preprocessing import image
# import time

# start_time_all = time.time()


# save_dir = '../../ta-hsi-datacenter/output_results/result_image'
# if not os.path.exists(save_dir):
#     os.makedirs(save_dir)

# # Start training loop
# start = 0
# start_time = time.time()

# low_iteration = 600
# high_iteration = 1000
# pre_low_step = 55300
# pre_high_step = 5700
# batch_size = 16
# for step in range(iterations):
#     for low_step in range(low_iteration):
#         real_images = next(datagen_train_2x)[0]
# #         stop = start+batch_size
# #         real_images = x_train[start: stop]
# #         batch_size = real_images.shape[0]
#         random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
        
        
#         generated_images = G1.predict(random_latent_vectors)
        
#         labels = np.concatenate([np.zeros((batch_size, 1)),
#                              np.ones((batch_size, 1))])

#         labels_real = np.ones((batch_size, 1)) - 0.05*np.abs(np.random.random((batch_size, 1)))
#         labels_fake = np.zeros((batch_size, 1)) + 0.05*np.abs(np.random.random((batch_size, 1)))

#         d_loss_real = D1.train_on_batch(real_images, labels_real)
#         d_loss_fake = D1.train_on_batch(generated_images, labels_fake)
#         d_loss = 0.5*np.add(d_loss_real, d_loss_fake)

#         random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

#         misleading_targets = np.ones((batch_size, 1))

#         g_loss = GAN1.train_on_batch(random_latent_vectors, misleading_targets)
# #         start += batch_size
# #         if start > len(x_train) - batch_size:
# #             start = 0

#         if low_step % 100 == 0:
#             # Save model weights
#             GAN1.save_weights('../../ta-hsi-datacenter/output_results/weight/gan1.h5')
#             G1.save_weights('../../ta-hsi-datacenter/output_results/weight/g1.h5')
#             D1.save_weights('../../ta-hsi-datacenter/output_results/weight/d1.h5')

#             # Print metrics
#             print('low resolution, discriminator loss at step %s: %s' % (step*low_iteration+low_step+pre_low_step, d_loss))
#             print('low resolution, adversarial loss at step %s: %s' % (step*low_iteration+low_step+pre_low_step, g_loss))
#             display_grid = np.zeros((4*height_1,width_1,3))
        
#             for j in range(4):
#                 display_grid[j*height_1:(j+1)*height_1,0:width_1,:] = generated_images[j]
        
#             img = image.array_to_img((display_grid[:,:,::-1]*127.5)+127.5, scale=False)
#             img.save(os.path.join(save_dir, 'low_generated_' + str(step*low_iteration+low_step+pre_low_step) + '.png'))
#             print("--- %s seconds ---" % (time.time() - start_time))
#             start_time = time.time()

# %%
#G_split = [7,9,11,13,15]
#D_split = [3,5,7,9,14]

# %%
split_layers = {0:[7,15,3,14],1:[9,15,5,14],2:[11,15,7,14],3:[13,15,9,14],4:[15,15,14,14]}

# %%
# plt.imshow(np.array(imgs_arr[0][0]*255,dtype=np.int))

# %%
import os
from keras.preprocessing import image
import time

start_time_all = time.time()


save_dir = '../../ta-hsi-datacenter/output_results/result_image/'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Start training loop
start = 0
start_time = time.time()

low_iteration = 600
high_iteration = 1000
pre_low_step = 0
pre_high_step = 0
batch_size = 8

batch_num = len(imgs_arr[0])//batch_size
# imgs_temp = imgs[:batch_size*batch_num]


for idx,imgs in enumerate(imgs_arr):
    imgs_temp = imgs[:batch_size*batch_num]
    
    for step in range(iterations):
        imgs_temp = shuffle(imgs_temp)

        ## 每一次epoch 都要慢慢解鎖layer
        for num_split,split_loc_arr in split_layers.items():
            imgs_temp = imgs_arr[num_split][:batch_size*batch_num]
            imgs_temp = shuffle(imgs_temp)
            if num_split!=4:
                ###############
                g_split_start , g_split_end , d_split_start , d_split_end = split_loc_arr[0],split_loc_arr[1],split_loc_arr[2],split_loc_arr[3]
                ## generator部分上鎖
                for k in range(g_split_start,g_split_end):
                    G1.layers[k].trainable=False
                ## discriminator部分上鎖
                for k in range(d_split_start,d_split_end):
                    D1.layers[k].trainable=False
                ###############    

        for low_step in range(batch_num):
            real_images = imgs_temp[low_step*batch_size:(low_step+1)*batch_size]
            real_images = (real_images-0.5)*2
            random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))


            generated_images = G1.predict(random_latent_vectors)

            labels = np.concatenate([np.zeros((batch_size, 1)),
                                 np.ones((batch_size, 1))])

    #         labels_real = np.ones((batch_size, 1)) - 0.05*np.abs(np.random.random((batch_size, 1)))
    #         labels_fake = np.zeros((batch_size, 1)) + 0.05*np.abs(np.random.random((batch_size, 1)))

            labels_real = 0.9*np.ones((batch_size, 1)) 
            labels_fake = np.zeros((batch_size, 1)) 

            d_loss_real = D1.train_on_batch(real_images, labels_real)
            d_loss_fake = D1.train_on_batch(generated_images, labels_fake)
            d_loss = 0.5*np.add(d_loss_real, d_loss_fake)

            #### discriminator部分解鎖
            for i in range(d_split_start,d_split_end):
                D1.layers[i].trainable=True

            random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

            misleading_targets = np.ones((batch_size, 1))

            g_loss = GAN1.train_on_batch(random_latent_vectors, misleading_targets)


            if low_step % 100 == 0:
                # Save model weights
                GAN1.save_weights('../../ta-hsi-datacenter/output_results/weight/gan1.h5')
                G1.save_weights('../../ta-hsi-datacenter/output_results/weight/g1.h5')
                D1.save_weights('../../ta-hsi-datacenter/output_results/weight/d1.h5')
                
                # Print metrics
                print('level_{}'.format(idx))
                print('low resolution, discriminator loss at step %s: %s' % (step*low_iteration+low_step+pre_low_step, d_loss))
                print('low resolution, adversarial loss at step %s: %s' % (step*low_iteration+low_step+pre_low_step, g_loss))
                display_grid = np.zeros((4*height_1,width_1,3))

                for j in range(4):
                    display_grid[j*height_1:(j+1)*height_1,0:width_1,:] = generated_images[j]
                
                img = image.array_to_img((display_grid[:,:,::-1]*127.5)+127.5, scale=False)
                img.save(os.path.join(save_dir, 'level_{}_low_generated_'.format(idx) + str(step*low_iteration+low_step+pre_low_step) + '.png'))
                print("--- %s seconds ---" % (time.time() - start_time))
                start_time = time.time()

            if num_split!=4:
                ## generator部分解鎖
                for k in range(g_split_start,g_split_end):
                    G1.layers[k].trainable=True
                ## discriminator部分解鎖
                for k in range(d_split_start,d_split_end):
                    D1.layers[k].trainable=True
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0427 08:18:04.069864 139776457041728 training.py:2131] Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# W0427 08:18:05.094254 139776457041728 training.py:2131] Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# level_0
# low resolution, discriminator loss at step 0: 0.7034467458724976
# low resolution, adversarial loss at step 0: 0.69073665
# --- 9.645214080810547 seconds ---
# level_0
# low resolution, discriminator loss at step 100: 0.188998743891716
# low resolution, adversarial loss at step 100: 3.7561991
# --- 18.692368030548096 seconds ---
# level_0
# low resolution, discriminator loss at step 200: 0.46245941519737244
# low resolution, adversarial loss at step 200: 2.6898224
# --- 19.121299743652344 seconds ---
# level_0
# low resolution, discriminator loss at step 300: 0.3150125741958618
# low resolution, adversarial loss at step 300: 2.2231283
# --- 18.90778422355652 seconds ---
# level_0
# low resolution, discriminator loss at step 400: 0.3969303369522095
# low resolution, adversarial loss at step 400: 4.3629055
# --- 18.99705743789673 seconds ---
# level_0
# low resolution, discriminator loss at step 500: 0.4045189619064331
# low resolution, adversarial loss at step 500: 2.282442
# --- 19.009223699569702 seconds ---
# level_0
# low resolution, discriminator loss at step 600: 0.23996731638908386
# low resolution, adversarial loss at step 600: 3.3251333
# --- 19.000433206558228 seconds ---
# level_0
# low resolution, discriminator loss at step 700: 0.4583657681941986
# low resolution, adversarial loss at step 700: 3.0477889
# --- 18.63081669807434 seconds ---
# level_0
# low resolution, discriminator loss at step 800: 0.5605553388595581
# low resolution, adversarial loss at step 800: 1.9214041
# --- 18.479907035827637 seconds ---
# level_0
# low resolution, discriminator loss at step 900: 0.5611545443534851
# low resolution, adversarial loss at step 900: 1.4258008
# --- 18.70824408531189 seconds ---
# level_0
# low resolution, discriminator loss at step 1000: 0.6909786462783813
# low resolution, adversarial loss at step 1000: 0.97206765
# --- 18.869624853134155 seconds ---
# level_0
# low resolution, discriminator loss at step 600: 0.6048967838287354
# low resolution, adversarial loss at step 600: 1.7466124
# --- 8.987391233444214 seconds ---
# level_0
# low resolution, discriminator loss at step 700: 0.5129086971282959
# low resolution, adversarial loss at step 700: 1.607569
# --- 19.045594215393066 seconds ---
# level_0
# low resolution, discriminator loss at step 800: 0.5522132515907288
# low resolution, adversarial loss at step 800: 1.5676293
# --- 18.608820915222168 seconds ---
# level_0
# low resolution, discriminator loss at step 900: 0.6990293264389038
# low resolution, adversarial loss at step 900: 1.2390288
# --- 30.228796243667603 seconds ---
# level_0
# low resolution, discriminator loss at step 1000: 0.675744354724884
# low resolution, adversarial loss at step 1000: 2.3557892
# --- 25.574191093444824 seconds ---
# level_0
# low resolution, discriminator loss at step 1100: 0.46527135372161865
# low resolution, adversarial loss at step 1100: 1.4446955
# --- 26.30690908432007 seconds ---
# level_0
# low resolution, discriminator loss at step 1200: 0.501760721206665
# low resolution, adversarial loss at step 1200: 1.4804022
# --- 22.532951831817627 seconds ---
# level_0
# low resolution, discriminator loss at step 1300: 0.5193092226982117
# low resolution, adversarial loss at step 1300: 1.5524721
# --- 28.229058027267456 seconds ---
# level_0
# low resolution, discriminator loss at step 1400: 0.6380020380020142
# low resolution, adversarial loss at step 1400: 1.6221254
# --- 29.15233874320984 seconds ---
# level_0
# low resolution, discriminator loss at step 1500: 0.5139734745025635
# low resolution, adversarial loss at step 1500: 1.3395376
# --- 32.81446695327759 seconds ---
# level_0
# low resolution, discriminator loss at step 1600: 0.6312963962554932
# low resolution, adversarial loss at step 1600: 1.2560148
# --- 23.398232221603394 seconds ---
# level_0
# low resolution, discriminator loss at step 1200: 0.47594350576400757
# low resolution, adversarial loss at step 1200: 2.9314363
# --- 12.457727193832397 seconds ---
# level_0
# low resolution, discriminator loss at step 1300: 0.6870629787445068
# low resolution, adversarial loss at step 1300: 1.3350315
# --- 24.832802057266235 seconds ---
# level_0
# low resolution, discriminator loss at step 1400: 0.6349211931228638
# low resolution, adversarial loss at step 1400: 1.5082617
# --- 24.7682466506958 seconds ---
# level_0
# low resolution, discriminator loss at step 1500: 0.4404480457305908
# low resolution, adversarial loss at step 1500: 2.4035568
# --- 19.119691133499146 seconds ---
# level_0
# low resolution, discriminator loss at step 1600: 0.4624794125556946
# low resolution, adversarial loss at step 1600: 1.6536844
# --- 23.500552892684937 seconds ---
# level_0
# low resolution, discriminator loss at step 1700: 0.48140472173690796
# low resolution, adversarial loss at step 1700: 1.464747
# --- 18.881713151931763 seconds ---
# level_0
# low resolution, discriminator loss at step 1800: 0.5132766962051392
# low resolution, adversarial loss at step 1800: 1.5844713
# --- 18.538164377212524 seconds ---
# level_0
# low resolution, discriminator loss at step 1900: 0.6686349511146545
# low resolution, adversarial loss at step 1900: 1.5235385
# --- 18.638370513916016 seconds ---
# level_0
# low resolution, discriminator loss at step 2000: 0.5848643779754639
# low resolution, adversarial loss at step 2000: 2.3754478
# --- 27.21533989906311 seconds ---
# level_0
# low resolution, discriminator loss at step 2100: 0.4776548147201538
# low resolution, adversarial loss at step 2100: 1.8717515
# --- 32.81260275840759 seconds ---
# level_0
# low resolution, discriminator loss at step 2200: 0.41130563616752625
# low resolution, adversarial loss at step 2200: 1.548763
# --- 28.349847316741943 seconds ---
# level_0
# low resolution, discriminator loss at step 1800: 0.68974369764328
# low resolution, adversarial loss at step 1800: 1.6238258
# --- 21.63492178916931 seconds ---
# level_0
# low resolution, discriminator loss at step 1900: 0.5922077298164368
# low resolution, adversarial loss at step 1900: 1.6072371
# --- 30.126758098602295 seconds ---
# level_0
# low resolution, discriminator loss at step 2000: 0.38186201453208923
# low resolution, adversarial loss at step 2000: 1.8771275
# --- 31.053884029388428 seconds ---
# level_0
# low resolution, discriminator loss at step 2100: 0.5063737630844116
# low resolution, adversarial loss at step 2100: 2.039641
# --- 33.76087427139282 seconds ---
# level_0
# low resolution, discriminator loss at step 2200: 0.34616345167160034
# low resolution, adversarial loss at step 2200: 1.9720937
# --- 39.08999562263489 seconds ---
# level_0
# low resolution, discriminator loss at step 2300: 0.5013723373413086
# low resolution, adversarial loss at step 2300: 1.5660057
# --- 30.20479464530945 seconds ---
# level_0
# low resolution, discriminator loss at step 2400: 0.4473804831504822
# low resolution, adversarial loss at step 2400: 1.8455665
# --- 26.341697692871094 seconds ---
# level_0
# low resolution, discriminator loss at step 2500: 0.6079800128936768
# low resolution, adversarial loss at step 2500: 1.5788479
# --- 26.376203775405884 seconds ---
# level_0
# low resolution, discriminator loss at step 2600: 0.4647732079029083
# low resolution, adversarial loss at step 2600: 1.9074724
# --- 18.748010873794556 seconds ---
# level_0
# low resolution, discriminator loss at step 2700: 0.4970017075538635
# low resolution, adversarial loss at step 2700: 1.6558492
# --- 18.639967918395996 seconds ---
# level_0
# low resolution, discriminator loss at step 2800: 0.41075971722602844
# low resolution, adversarial loss at step 2800: 1.858875
# --- 18.582839488983154 seconds ---
# level_0
# low resolution, discriminator loss at step 2400: 0.5680397748947144
# low resolution, adversarial loss at step 2400: 1.8502121
# --- 9.617603063583374 seconds ---
# level_0
# low resolution, discriminator loss at step 2500: 0.48596760630607605
# low resolution, adversarial loss at step 2500: 1.5055804
# --- 18.50170660018921 seconds ---
# level_0
# low resolution, discriminator loss at step 2600: 0.6803796291351318
# low resolution, adversarial loss at step 2600: 2.0839038
# --- 19.264745950698853 seconds ---
# level_0
# low resolution, discriminator loss at step 2700: 0.43288224935531616
# low resolution, adversarial loss at step 2700: 1.9631252
# --- 18.61619257926941 seconds ---
# level_0
# low resolution, discriminator loss at step 2800: 0.41489309072494507
# low resolution, adversarial loss at step 2800: 1.8268527
# --- 18.605278968811035 seconds ---
# level_0
# low resolution, discriminator loss at step 2900: 0.4771358370780945
# low resolution, adversarial loss at step 2900: 1.3849823
# --- 18.64088463783264 seconds ---
# level_0
# low resolution, discriminator loss at step 3000: 0.44413667917251587
# low resolution, adversarial loss at step 3000: 1.6240883
# --- 18.762754678726196 seconds ---
# level_0
# low resolution, discriminator loss at step 3100: 0.3720244765281677
# low resolution, adversarial loss at step 3100: 2.0176558
# --- 18.553902864456177 seconds ---
# level_0
# low resolution, discriminator loss at step 3200: 0.4094030261039734
# low resolution, adversarial loss at step 3200: 2.0626252
# --- 18.601208925247192 seconds ---
# level_0
# low resolution, discriminator loss at step 3300: 0.4712299108505249
# low resolution, adversarial loss at step 3300: 1.4155751
# --- 18.66586971282959 seconds ---
# level_0
# low resolution, discriminator loss at step 3400: 0.40075215697288513
# low resolution, adversarial loss at step 3400: 1.6359402
# --- 18.53624200820923 seconds ---
# level_0
# low resolution, discriminator loss at step 3500: 0.2929987907409668
# low resolution, adversarial loss at step 3500: 2.6286979
# --- 25.171011209487915 seconds ---
# level_0
# low resolution, discriminator loss at step 3600: 0.6808909773826599
# low resolution, adversarial loss at step 3600: 1.9407411
# --- 24.254518747329712 seconds ---
# level_0
# low resolution, discriminator loss at step 3700: 0.458915114402771
# low resolution, adversarial loss at step 3700: 2.027892
# --- 25.503555297851562 seconds ---
# level_0
# low resolution, discriminator loss at step 3800: 0.7918856143951416
# low resolution, adversarial loss at step 3800: 2.08151
# --- 24.181044816970825 seconds ---
# level_0
# low resolution, discriminator loss at step 3900: 0.49414491653442383
# low resolution, adversarial loss at step 3900: 2.4356894
# --- 26.37174701690674 seconds ---
# level_0
# low resolution, discriminator loss at step 4000: 0.36661913990974426
# low resolution, adversarial loss at step 4000: 1.9816589
# --- 18.688697576522827 seconds ---
# level_0
# low resolution, discriminator loss at step 3600: 0.34632617235183716
# low resolution, adversarial loss at step 3600: 2.3973446
# --- 8.777204275131226 seconds ---
# level_0
# low resolution, discriminator loss at step 3700: 0.7683058977127075
# low resolution, adversarial loss at step 3700: 2.1042247
# --- 18.870396375656128 seconds ---
# level_0
# low resolution, discriminator loss at step 3800: 0.3772432208061218
# low resolution, adversarial loss at step 3800: 1.6937995
# --- 19.02612042427063 seconds ---
# level_0
# low resolution, discriminator loss at step 3900: 0.38849860429763794
# low resolution, adversarial loss at step 3900: 2.5579588
# --- 18.699421167373657 seconds ---
# level_0
# low resolution, discriminator loss at step 4000: 0.4190111756324768
# low resolution, adversarial loss at step 4000: 2.0272074
# --- 18.450196743011475 seconds ---
# level_0
# low resolution, discriminator loss at step 4100: 0.5420889258384705
# low resolution, adversarial loss at step 4100: 1.6789527
# --- 18.735685110092163 seconds ---
# level_0
# low resolution, discriminator loss at step 4200: 0.4478132426738739
# low resolution, adversarial loss at step 4200: 2.3057897
# --- 18.711565256118774 seconds ---
# level_0
# low resolution, discriminator loss at step 4300: 0.48317670822143555
# low resolution, adversarial loss at step 4300: 2.065615
# --- 18.73287296295166 seconds ---
# level_0
# low resolution, discriminator loss at step 4400: 0.5405877828598022
# low resolution, adversarial loss at step 4400: 2.3090825
# --- 18.933827877044678 seconds ---
# level_0
# low resolution, discriminator loss at step 4500: 0.49198153614997864
# low resolution, adversarial loss at step 4500: 1.9940233
# --- 18.6672146320343 seconds ---
# level_0
# low resolution, discriminator loss at step 4600: 0.3993089199066162
# low resolution, adversarial loss at step 4600: 1.8932284
# --- 26.127246618270874 seconds ---
# level_0
# low resolution, discriminator loss at step 4200: 0.38449981808662415
# low resolution, adversarial loss at step 4200: 2.245007
# --- 14.572750806808472 seconds ---
# level_0
# low resolution, discriminator loss at step 4300: 0.2949811816215515
# low resolution, adversarial loss at step 4300: 2.1538615
# --- 23.5139377117157 seconds ---
# level_0
# low resolution, discriminator loss at step 4400: 0.6204172968864441
# low resolution, adversarial loss at step 4400: 1.5396826
# --- 32.28221249580383 seconds ---
# level_0
# low resolution, discriminator loss at step 4500: 0.6044301390647888
# low resolution, adversarial loss at step 4500: 1.5280344
# --- 24.790886640548706 seconds ---
# level_0
# low resolution, discriminator loss at step 4600: 0.4714430272579193
# low resolution, adversarial loss at step 4600: 2.279694
# --- 24.476483583450317 seconds ---
# level_0
# low resolution, discriminator loss at step 4700: 0.6387655735015869
# low resolution, adversarial loss at step 4700: 1.5947258
# --- 22.42074751853943 seconds ---
# level_0
# low resolution, discriminator loss at step 4800: 0.5905080437660217
# low resolution, adversarial loss at step 4800: 2.0524273
# --- 29.831056833267212 seconds ---
# level_0
# low resolution, discriminator loss at step 4900: 0.5854983329772949
# low resolution, adversarial loss at step 4900: 1.6583257
# --- 25.540799379348755 seconds ---
# level_0
# low resolution, discriminator loss at step 5000: 0.4745104908943176
# low resolution, adversarial loss at step 5000: 1.4685705
# --- 19.60873794555664 seconds ---
# level_0
# low resolution, discriminator loss at step 5100: 0.8139759302139282
# low resolution, adversarial loss at step 5100: 3.9302416
# --- 18.372333765029907 seconds ---
# level_0
# low resolution, discriminator loss at step 5200: 0.47185415029525757
# low resolution, adversarial loss at step 5200: 2.2742372
# --- 18.842853784561157 seconds ---
# level_0
# low resolution, discriminator loss at step 4800: 0.4059911072254181
# low resolution, adversarial loss at step 4800: 2.0362115
# --- 9.060933828353882 seconds ---
# level_0
# low resolution, discriminator loss at step 4900: 0.5642352104187012
# low resolution, adversarial loss at step 4900: 1.8211088
# --- 18.51362180709839 seconds ---
# level_0
# low resolution, discriminator loss at step 5000: 0.43171048164367676
# low resolution, adversarial loss at step 5000: 1.8591634
# --- 18.578686714172363 seconds ---
# level_0
# low resolution, discriminator loss at step 5100: 0.4236738383769989
# low resolution, adversarial loss at step 5100: 2.3796198
# --- 18.66374397277832 seconds ---
# level_0
# low resolution, discriminator loss at step 5200: 0.3382657766342163
# low resolution, adversarial loss at step 5200: 3.1914124
# --- 18.884520769119263 seconds ---
# level_0
# low resolution, discriminator loss at step 5300: 0.5503492951393127
# low resolution, adversarial loss at step 5300: 2.203339
# --- 19.01043462753296 seconds ---
# level_0
# low resolution, discriminator loss at step 5400: 0.409105122089386
# low resolution, adversarial loss at step 5400: 1.664655
# --- 18.869417905807495 seconds ---
# level_0
# low resolution, discriminator loss at step 5500: 0.5153038501739502
# low resolution, adversarial loss at step 5500: 1.8337232
# --- 18.780046224594116 seconds ---
# level_0
# low resolution, discriminator loss at step 5600: 0.4404546022415161
# low resolution, adversarial loss at step 5600: 2.0195856
# --- 19.138949871063232 seconds ---
# level_0
# low resolution, discriminator loss at step 5700: 0.4085843861103058
# low resolution, adversarial loss at step 5700: 2.7213416
# --- 18.83056664466858 seconds ---
# level_0
# low resolution, discriminator loss at step 5800: 0.4889990985393524
# low resolution, adversarial loss at step 5800: 1.9692178
# --- 18.50747799873352 seconds ---
# level_0
# low resolution, discriminator loss at step 5400: 0.4241093397140503
# low resolution, adversarial loss at step 5400: 2.658664
# --- 8.803378343582153 seconds ---
# level_0
# low resolution, discriminator loss at step 5500: 0.5825104117393494
# low resolution, adversarial loss at step 5500: 2.106158
# --- 18.85194706916809 seconds ---
# level_0
# low resolution, discriminator loss at step 5600: 0.4712613821029663
# low resolution, adversarial loss at step 5600: 1.9628439
# --- 19.518858909606934 seconds ---
# level_0
# low resolution, discriminator loss at step 5700: 0.43925419449806213
# low resolution, adversarial loss at step 5700: 2.801055
# --- 18.780142068862915 seconds ---
# level_0
# low resolution, discriminator loss at step 5800: 0.4924417734146118
# low resolution, adversarial loss at step 5800: 2.4226336
# --- 18.541974782943726 seconds ---
# level_0
# low resolution, discriminator loss at step 5900: 0.4741819500923157
# low resolution, adversarial loss at step 5900: 1.6994362
# --- 18.786518573760986 seconds ---
# level_0
# low resolution, discriminator loss at step 6000: 0.33497169613838196
# low resolution, adversarial loss at step 6000: 2.2625422
# --- 18.666999340057373 seconds ---
# level_0
# low resolution, discriminator loss at step 6100: 0.5857798457145691
# low resolution, adversarial loss at step 6100: 2.4656353
# --- 18.62379503250122 seconds ---
# level_0
# low resolution, discriminator loss at step 6200: 0.5614383816719055
# low resolution, adversarial loss at step 6200: 1.9946176
# --- 18.67907214164734 seconds ---
# level_0
# low resolution, discriminator loss at step 6300: 0.7170872688293457
# low resolution, adversarial loss at step 6300: 2.4448886
# --- 18.59499979019165 seconds ---
# level_0
# low resolution, discriminator loss at step 6400: 0.5432661771774292
# low resolution, adversarial loss at step 6400: 1.8563772
# --- 18.75851798057556 seconds ---
# level_0
# low resolution, discriminator loss at step 6000: 0.5964726209640503
# low resolution, adversarial loss at step 6000: 1.8163174
# --- 8.774813413619995 seconds ---
# level_0
# low resolution, discriminator loss at step 6100: 0.7143082618713379
# low resolution, adversarial loss at step 6100: 1.7516558
# --- 18.564711332321167 seconds ---
# level_0
# low resolution, discriminator loss at step 6200: 0.4672624468803406
# low resolution, adversarial loss at step 6200: 2.6606312
# --- 18.465462923049927 seconds ---
# level_0
# low resolution, discriminator loss at step 6300: 0.5481426119804382
# low resolution, adversarial loss at step 6300: 2.1471188
# --- 18.778149127960205 seconds ---
# level_0
# low resolution, discriminator loss at step 6400: 0.4305238723754883
# low resolution, adversarial loss at step 6400: 2.3483367
# --- 19.226641416549683 seconds ---
# level_0
# low resolution, discriminator loss at step 6500: 0.6537009477615356
# low resolution, adversarial loss at step 6500: 2.0226805
# --- 18.460334300994873 seconds ---
# level_0
# low resolution, discriminator loss at step 6600: 0.38979849219322205
# low resolution, adversarial loss at step 6600: 2.7183304
# --- 18.685367584228516 seconds ---
# level_0
# low resolution, discriminator loss at step 6700: 0.7761640548706055
# low resolution, adversarial loss at step 6700: 1.8165278
# --- 18.9067599773407 seconds ---
# level_0
# low resolution, discriminator loss at step 6800: 0.32488399744033813
# low resolution, adversarial loss at step 6800: 2.8285801
# --- 18.596656799316406 seconds ---
# level_0
# low resolution, discriminator loss at step 6900: 0.5578604936599731
# low resolution, adversarial loss at step 6900: 1.7279537
# --- 19.401000261306763 seconds ---
# level_0
# low resolution, discriminator loss at step 7000: 0.3823285400867462
# low resolution, adversarial loss at step 7000: 1.642066
# --- 18.854029893875122 seconds ---
# level_0
# low resolution, discriminator loss at step 6600: 0.5424098372459412
# low resolution, adversarial loss at step 6600: 1.7442645
# --- 9.464071273803711 seconds ---
# level_0
# low resolution, discriminator loss at step 6700: 0.46986210346221924
# low resolution, adversarial loss at step 6700: 2.0486693
# --- 18.55739998817444 seconds ---
# level_0
# low resolution, discriminator loss at step 6800: 0.5649063587188721
# low resolution, adversarial loss at step 6800: 2.2349148
# --- 18.918602228164673 seconds ---
# level_0
# low resolution, discriminator loss at step 6900: 0.4184410572052002
# low resolution, adversarial loss at step 6900: 3.219861
# --- 18.424476385116577 seconds ---
# level_0
# low resolution, discriminator loss at step 7000: 0.6136189103126526
# low resolution, adversarial loss at step 7000: 2.1740146
# --- 19.315659046173096 seconds ---
# level_0
# low resolution, discriminator loss at step 7100: 0.661760687828064
# low resolution, adversarial loss at step 7100: 2.0133724
# --- 18.741528511047363 seconds ---
# level_0
# low resolution, discriminator loss at step 7200: 0.5387870073318481
# low resolution, adversarial loss at step 7200: 1.6718904
# --- 18.901148557662964 seconds ---
# level_0
# low resolution, discriminator loss at step 7300: 0.4956855773925781
# low resolution, adversarial loss at step 7300: 1.4165245
# --- 18.556610107421875 seconds ---
# level_0
# low resolution, discriminator loss at step 7400: 0.6451711654663086
# low resolution, adversarial loss at step 7400: 2.4546547
# --- 18.842649698257446 seconds ---
# level_0
# low resolution, discriminator loss at step 7500: 0.30697622895240784
# low resolution, adversarial loss at step 7500: 2.1687062
# --- 18.71146821975708 seconds ---
# level_0
# low resolution, discriminator loss at step 7600: 0.6315624713897705
# low resolution, adversarial loss at step 7600: 2.120172
# --- 18.98655605316162 seconds ---
# level_0
# low resolution, discriminator loss at step 7200: 0.520456850528717
# low resolution, adversarial loss at step 7200: 2.0395186
# --- 8.847236633300781 seconds ---
# level_0
# low resolution, discriminator loss at step 7300: 0.4447318911552429
# low resolution, adversarial loss at step 7300: 2.3438873
# --- 18.63466215133667 seconds ---
# level_0
# low resolution, discriminator loss at step 7400: 0.5236828923225403
# low resolution, adversarial loss at step 7400: 1.5686469
# --- 18.69187068939209 seconds ---
# level_0
# low resolution, discriminator loss at step 7500: 0.4606994390487671
# low resolution, adversarial loss at step 7500: 1.9028912
# --- 19.202147483825684 seconds ---
# level_0
# low resolution, discriminator loss at step 7600: 0.4522917568683624
# low resolution, adversarial loss at step 7600: 1.6203635
# --- 18.859710454940796 seconds ---
# level_0
# low resolution, discriminator loss at step 7700: 0.6506831049919128
# low resolution, adversarial loss at step 7700: 1.9091799
# --- 18.72876214981079 seconds ---
# level_0
# low resolution, discriminator loss at step 7800: 0.4935757517814636
# low resolution, adversarial loss at step 7800: 2.1168504
# --- 19.07392930984497 seconds ---
# level_0
# low resolution, discriminator loss at step 7900: 0.5252269506454468
# low resolution, adversarial loss at step 7900: 1.5184575
# --- 19.15886616706848 seconds ---
# level_0
# low resolution, discriminator loss at step 8000: 0.611973762512207
# low resolution, adversarial loss at step 8000: 1.9896353
# --- 18.75054121017456 seconds ---
# level_0
# low resolution, discriminator loss at step 8100: 0.6950973272323608
# low resolution, adversarial loss at step 8100: 1.6306865
# --- 18.750536680221558 seconds ---
# level_0
# low resolution, discriminator loss at step 8200: 0.4124608039855957
# low resolution, adversarial loss at step 8200: 2.3583038
# --- 19.40025568008423 seconds ---
# level_0
# low resolution, discriminator loss at step 7800: 0.5139192342758179
# low resolution, adversarial loss at step 7800: 1.4709194
# --- 9.209982872009277 seconds ---
# level_0
# low resolution, discriminator loss at step 7900: 0.5711352825164795
# low resolution, adversarial loss at step 7900: 1.7459272
# --- 18.916303157806396 seconds ---
# level_0
# low resolution, discriminator loss at step 8000: 0.4837319850921631
# low resolution, adversarial loss at step 8000: 1.6742941
# --- 19.275834321975708 seconds ---
# level_0
# low resolution, discriminator loss at step 8100: 0.4752199053764343
# low resolution, adversarial loss at step 8100: 2.4645426
# --- 18.59347105026245 seconds ---
# level_0
# low resolution, discriminator loss at step 8200: 0.5012143850326538
# low resolution, adversarial loss at step 8200: 1.6638844
# --- 18.90263843536377 seconds ---
# level_0
# low resolution, discriminator loss at step 8300: 0.4805665612220764
# low resolution, adversarial loss at step 8300: 2.1385288
# --- 18.550642013549805 seconds ---
# level_0
# low resolution, discriminator loss at step 8400: 0.39943820238113403
# low resolution, adversarial loss at step 8400: 2.3048735
# --- 25.665005445480347 seconds ---
# level_0
# low resolution, discriminator loss at step 8500: 0.5804663896560669
# low resolution, adversarial loss at step 8500: 1.1862603
# --- 23.22970986366272 seconds ---
# level_0
# low resolution, discriminator loss at step 8600: 0.6756888031959534
# low resolution, adversarial loss at step 8600: 1.4939692
# --- 28.066696643829346 seconds ---
# level_0
# low resolution, discriminator loss at step 8700: 0.5742983222007751
# low resolution, adversarial loss at step 8700: 1.2228866
# --- 22.51462745666504 seconds ---
# level_0
# low resolution, discriminator loss at step 8800: 0.5867478847503662
# low resolution, adversarial loss at step 8800: 1.3955005
# --- 27.71314835548401 seconds ---
# level_0
# low resolution, discriminator loss at step 8400: 0.45149680972099304
# low resolution, adversarial loss at step 8400: 2.518906
# --- 12.278342247009277 seconds ---
# level_0
# low resolution, discriminator loss at step 8500: 0.6410866975784302
# low resolution, adversarial loss at step 8500: 1.7288463
# --- 26.208566904067993 seconds ---
# level_0
# low resolution, discriminator loss at step 8600: 0.3037649393081665
# low resolution, adversarial loss at step 8600: 2.4614651
# --- 24.47407555580139 seconds ---
# level_0
# low resolution, discriminator loss at step 8700: 0.5937017798423767
# low resolution, adversarial loss at step 8700: 1.8447843
# --- 24.47874164581299 seconds ---
# level_0
# low resolution, discriminator loss at step 8800: 0.4473991394042969
# low resolution, adversarial loss at step 8800: 1.7892646
# --- 22.815169095993042 seconds ---
# level_0
# low resolution, discriminator loss at step 8900: 0.8756782412528992
# low resolution, adversarial loss at step 8900: 2.0094805
# --- 26.916504383087158 seconds ---
# level_0
# low resolution, discriminator loss at step 9000: 0.5019575357437134
# low resolution, adversarial loss at step 9000: 1.4890761
# --- 19.244028091430664 seconds ---
# level_0
# low resolution, discriminator loss at step 9100: 0.36088117957115173
# low resolution, adversarial loss at step 9100: 2.2890112
# --- 19.366844415664673 seconds ---
# level_0
# low resolution, discriminator loss at step 9200: 0.388077050447464
# low resolution, adversarial loss at step 9200: 2.1878457
# --- 18.7985942363739 seconds ---
# level_0
# low resolution, discriminator loss at step 9300: 0.5010753273963928
# low resolution, adversarial loss at step 9300: 1.4088356
# --- 18.64257574081421 seconds ---
# level_0
# low resolution, discriminator loss at step 9400: 0.33430153131484985
# low resolution, adversarial loss at step 9400: 2.339872
# --- 18.63129496574402 seconds ---
# level_0
# low resolution, discriminator loss at step 9000: 0.5101227760314941
# low resolution, adversarial loss at step 9000: 1.6818914
# --- 8.61714506149292 seconds ---
# level_0
# low resolution, discriminator loss at step 9100: 0.7607676982879639
# low resolution, adversarial loss at step 9100: 1.8335128
# --- 18.678134202957153 seconds ---
# level_0
# low resolution, discriminator loss at step 9200: 0.5567127466201782
# low resolution, adversarial loss at step 9200: 1.6701465
# --- 25.642924785614014 seconds ---
# level_0
# low resolution, discriminator loss at step 9300: 0.46052590012550354
# low resolution, adversarial loss at step 9300: 2.3073616
# --- 27.04894518852234 seconds ---
# level_0
# low resolution, discriminator loss at step 9400: 0.46907711029052734
# low resolution, adversarial loss at step 9400: 1.8730319
# --- 25.52881956100464 seconds ---
# level_0
# low resolution, discriminator loss at step 9500: 0.7886941432952881
# low resolution, adversarial loss at step 9500: 1.8998961
# --- 21.48405146598816 seconds ---
# level_0
# low resolution, discriminator loss at step 9600: 0.5450515151023865
# low resolution, adversarial loss at step 9600: 1.6400957
# --- 31.814354419708252 seconds ---
# level_0
# low resolution, discriminator loss at step 9700: 0.5921384692192078
# low resolution, adversarial loss at step 9700: 1.9928138
# --- 25.793285369873047 seconds ---
# level_0
# low resolution, discriminator loss at step 9800: 0.6106910109519958
# low resolution, adversarial loss at step 9800: 2.1267047
# --- 27.712865829467773 seconds ---
# level_0
# low resolution, discriminator loss at step 9900: 0.3869473934173584
# low resolution, adversarial loss at step 9900: 2.1522405
# --- 29.9712016582489 seconds ---
# level_0
# low resolution, discriminator loss at step 10000: 0.3692660331726074
# low resolution, adversarial loss at step 10000: 1.7739811
# --- 28.50864315032959 seconds ---
# level_0
# low resolution, discriminator loss at step 9600: 0.6505171060562134
# low resolution, adversarial loss at step 9600: 2.5579197
# --- 16.91071319580078 seconds ---
# level_0
# low resolution, discriminator loss at step 9700: 0.4530055820941925
# low resolution, adversarial loss at step 9700: 1.546402
# --- 25.075833082199097 seconds ---
# level_0
# low resolution, discriminator loss at step 9800: 0.727094292640686
# low resolution, adversarial loss at step 9800: 1.7329384
# --- 18.741990089416504 seconds ---
# level_0
# low resolution, discriminator loss at step 9900: 0.3794776201248169
# low resolution, adversarial loss at step 9900: 1.9880865
# --- 18.70129919052124 seconds ---
# level_0
# low resolution, discriminator loss at step 10000: 0.56535404920578
# low resolution, adversarial loss at step 10000: 1.5888066
# --- 19.41952657699585 seconds ---
# level_0
# low resolution, discriminator loss at step 10100: 0.3809173107147217
# low resolution, adversarial loss at step 10100: 1.8467321
# --- 18.848560571670532 seconds ---
# level_0
# low resolution, discriminator loss at step 10200: 0.5862441062927246
# low resolution, adversarial loss at step 10200: 2.0657678
# --- 18.81524968147278 seconds ---
# level_0
# low resolution, discriminator loss at step 10300: 0.5786967277526855
# low resolution, adversarial loss at step 10300: 2.4093978
# --- 19.337669610977173 seconds ---
# level_0
# low resolution, discriminator loss at step 10400: 0.6523946523666382
# low resolution, adversarial loss at step 10400: 1.1736877
# --- 19.313958883285522 seconds ---
# level_0
# low resolution, discriminator loss at step 10500: 0.4734276533126831
# low resolution, adversarial loss at step 10500: 1.4410361
# --- 19.248480796813965 seconds ---
# level_0
# low resolution, discriminator loss at step 10600: 0.4419320225715637
# low resolution, adversarial loss at step 10600: 1.4137268
# --- 18.857160568237305 seconds ---
# level_0
# low resolution, discriminator loss at step 10200: 0.2987852990627289
# low resolution, adversarial loss at step 10200: 2.4227884
# --- 8.85183310508728 seconds ---
# level_0
# low resolution, discriminator loss at step 10300: 0.3836534023284912
# low resolution, adversarial loss at step 10300: 1.6757997
# --- 19.90251398086548 seconds ---
# level_0
# low resolution, discriminator loss at step 10400: 0.27686357498168945
# low resolution, adversarial loss at step 10400: 2.5548353
# --- 18.925472736358643 seconds ---
# level_0
# low resolution, discriminator loss at step 10500: 0.6165227890014648
# low resolution, adversarial loss at step 10500: 1.5649896
# --- 20.336710929870605 seconds ---
# level_0
# low resolution, discriminator loss at step 10600: 0.4578886032104492
# low resolution, adversarial loss at step 10600: 1.5650501
# --- 18.826611518859863 seconds ---
# level_0
# low resolution, discriminator loss at step 10700: 0.4344719648361206
# low resolution, adversarial loss at step 10700: 1.9836143
# --- 20.16868805885315 seconds ---
# level_0
# low resolution, discriminator loss at step 10800: 0.47379738092422485
# low resolution, adversarial loss at step 10800: 1.3462361
# --- 18.849690437316895 seconds ---
# level_0
# low resolution, discriminator loss at step 10900: 0.6466811299324036
# low resolution, adversarial loss at step 10900: 1.7126396
# --- 20.756937742233276 seconds ---
# level_0
# low resolution, discriminator loss at step 11000: 0.7468297481536865
# low resolution, adversarial loss at step 11000: 1.5829587
# --- 19.00080418586731 seconds ---
# level_0
# low resolution, discriminator loss at step 11100: 0.37860405445098877
# low resolution, adversarial loss at step 11100: 2.085535
# --- 18.975743293762207 seconds ---
# level_0
# low resolution, discriminator loss at step 11200: 0.6448613405227661
# low resolution, adversarial loss at step 11200: 2.5130506
# --- 18.701035022735596 seconds ---
# level_0
# low resolution, discriminator loss at step 10800: 0.6439897418022156
# low resolution, adversarial loss at step 10800: 1.7825994
# --- 9.80242919921875 seconds ---
# level_0
# low resolution, discriminator loss at step 10900: 0.458509236574173
# low resolution, adversarial loss at step 10900: 1.633354
# --- 18.528774738311768 seconds ---
# level_0
# low resolution, discriminator loss at step 11000: 0.4027734100818634
# low resolution, adversarial loss at step 11000: 1.819839
# --- 19.422122955322266 seconds ---
# level_0
# low resolution, discriminator loss at step 11100: 0.4866153597831726
# low resolution, adversarial loss at step 11100: 2.0333374
# --- 18.560307264328003 seconds ---
# level_0
# low resolution, discriminator loss at step 11200: 0.5276415348052979
# low resolution, adversarial loss at step 11200: 1.9000595
# --- 18.947293043136597 seconds ---
# level_0
# low resolution, discriminator loss at step 11300: 0.6537003517150879
# low resolution, adversarial loss at step 11300: 0.9183628
# --- 18.793086528778076 seconds ---
# level_0
# low resolution, discriminator loss at step 11400: 0.35158073902130127
# low resolution, adversarial loss at step 11400: 2.1423411
# --- 19.024597644805908 seconds ---
# level_0
# low resolution, discriminator loss at step 11500: 0.2650477886199951
# low resolution, adversarial loss at step 11500: 2.7761564
# --- 23.441817045211792 seconds ---
# level_0
# low resolution, discriminator loss at step 11600: 0.603790283203125
# low resolution, adversarial loss at step 11600: 1.7537835
# --- 24.02833318710327 seconds ---
# level_0
# low resolution, discriminator loss at step 11700: 0.453147292137146
# low resolution, adversarial loss at step 11700: 1.9937112
# --- 23.509599447250366 seconds ---
# level_0
# low resolution, discriminator loss at step 11800: 0.32794228196144104
# low resolution, adversarial loss at step 11800: 2.2741222
# --- 21.725254774093628 seconds ---
# level_0
# low resolution, discriminator loss at step 11400: 0.5911090970039368
# low resolution, adversarial loss at step 11400: 1.2382945
# --- 15.184355735778809 seconds ---
# level_0
# low resolution, discriminator loss at step 11500: 0.6230438947677612
# low resolution, adversarial loss at step 11500: 1.8791646
# --- 23.303401708602905 seconds ---
# level_0
# low resolution, discriminator loss at step 11600: 0.4533233642578125
# low resolution, adversarial loss at step 11600: 2.3992057
# --- 23.82587766647339 seconds ---
# level_0
# low resolution, discriminator loss at step 11700: 0.4419967830181122
# low resolution, adversarial loss at step 11700: 2.0627866
# --- 23.887555837631226 seconds ---
# level_0
# low resolution, discriminator loss at step 11800: 0.5592038035392761
# low resolution, adversarial loss at step 11800: 2.3713362
# --- 19.53167223930359 seconds ---
# level_0
# low resolution, discriminator loss at step 11900: 0.6470080614089966
# low resolution, adversarial loss at step 11900: 1.8251852
# --- 21.386063814163208 seconds ---
# level_0
# low resolution, discriminator loss at step 12000: 0.4234675168991089
# low resolution, adversarial loss at step 12000: 2.5229535
# --- 21.90979290008545 seconds ---
# level_0
# low resolution, discriminator loss at step 12100: 0.41417497396469116
# low resolution, adversarial loss at step 12100: 2.1206656
# --- 20.561867475509644 seconds ---
# level_0
# low resolution, discriminator loss at step 12200: 0.6111725568771362
# low resolution, adversarial loss at step 12200: 1.8536758
# --- 25.48082685470581 seconds ---
# level_0
# low resolution, discriminator loss at step 12300: 0.7793916463851929
# low resolution, adversarial loss at step 12300: 2.0022368
# --- 25.78118872642517 seconds ---
# level_0
# low resolution, discriminator loss at step 12400: 0.41115790605545044
# low resolution, adversarial loss at step 12400: 1.4338672
# --- 18.629844903945923 seconds ---
# level_0
# low resolution, discriminator loss at step 12000: 0.5928846597671509
# low resolution, adversarial loss at step 12000: 2.2085462
# --- 8.804479598999023 seconds ---
# level_0
# low resolution, discriminator loss at step 12100: 0.6521121859550476
# low resolution, adversarial loss at step 12100: 1.315536
# --- 18.813743591308594 seconds ---
# level_0
# low resolution, discriminator loss at step 12200: 0.6629913449287415
# low resolution, adversarial loss at step 12200: 1.3832039
# --- 18.787639379501343 seconds ---
# level_0
# low resolution, discriminator loss at step 12300: 0.4370388388633728
# low resolution, adversarial loss at step 12300: 2.5710971
# --- 18.88291072845459 seconds ---
# level_0
# low resolution, discriminator loss at step 12400: 0.4534408450126648
# low resolution, adversarial loss at step 12400: 1.6337552
# --- 18.85317373275757 seconds ---
# level_0
# low resolution, discriminator loss at step 12500: 0.42796140909194946
# low resolution, adversarial loss at step 12500: 2.1578147
# --- 19.32387614250183 seconds ---
# level_0
# low resolution, discriminator loss at step 12600: 0.4572698771953583
# low resolution, adversarial loss at step 12600: 1.7642555
# --- 18.714994430541992 seconds ---
# level_0
# low resolution, discriminator loss at step 12700: 0.41612792015075684
# low resolution, adversarial loss at step 12700: 1.5336261
# --- 23.761507987976074 seconds ---
# level_0
# low resolution, discriminator loss at step 12800: 0.481569766998291
# low resolution, adversarial loss at step 12800: 2.119536
# --- 24.289504289627075 seconds ---
# level_0
# low resolution, discriminator loss at step 12900: 0.5855364203453064
# low resolution, adversarial loss at step 12900: 1.8089645
# --- 25.581073999404907 seconds ---
# level_0
# low resolution, discriminator loss at step 13000: 0.6528432965278625
# low resolution, adversarial loss at step 13000: 1.7084835
# --- 26.411031484603882 seconds ---
# level_0
# low resolution, discriminator loss at step 12600: 0.6109985709190369
# low resolution, adversarial loss at step 12600: 1.4885771
# --- 36.32682228088379 seconds ---
# level_0
# low resolution, discriminator loss at step 12700: 0.5766772031784058
# low resolution, adversarial loss at step 12700: 1.9877352
# --- 64.46501779556274 seconds ---
# level_0
# low resolution, discriminator loss at step 12800: 0.40197479724884033
# low resolution, adversarial loss at step 12800: 2.1436949
# --- 60.3975088596344 seconds ---
# level_0
# low resolution, discriminator loss at step 12900: 0.4099094569683075
# low resolution, adversarial loss at step 12900: 2.507327
# --- 24.137977600097656 seconds ---
# level_0
# low resolution, discriminator loss at step 13000: 0.38046371936798096
# low resolution, adversarial loss at step 13000: 2.4451678
# --- 23.356146335601807 seconds ---
# level_0
# low resolution, discriminator loss at step 13100: 0.57695472240448
# low resolution, adversarial loss at step 13100: 1.9102206
# --- 25.625427961349487 seconds ---
# level_0
# low resolution, discriminator loss at step 13200: 0.701904296875
# low resolution, adversarial loss at step 13200: 2.5113654
# --- 25.190418243408203 seconds ---
# level_0
# low resolution, discriminator loss at step 13300: 0.371966153383255
# low resolution, adversarial loss at step 13300: 2.023021
# --- 25.205565452575684 seconds ---
# level_0
# low resolution, discriminator loss at step 13400: 0.4604063928127289
# low resolution, adversarial loss at step 13400: 2.464672
# --- 25.197965145111084 seconds ---
# level_0
# low resolution, discriminator loss at step 13500: 0.3658125698566437
# low resolution, adversarial loss at step 13500: 2.3730881
# --- 18.451519012451172 seconds ---
# level_0
# low resolution, discriminator loss at step 13600: 0.3892703354358673
# low resolution, adversarial loss at step 13600: 1.730737
# --- 18.861330270767212 seconds ---
# level_0
# low resolution, discriminator loss at step 13200: 0.5715601444244385
# low resolution, adversarial loss at step 13200: 2.124524
# --- 9.472119569778442 seconds ---
# level_0
# low resolution, discriminator loss at step 13300: 0.5361476540565491
# low resolution, adversarial loss at step 13300: 2.9374108
# --- 18.834712028503418 seconds ---
# level_0
# low resolution, discriminator loss at step 13400: 0.44558146595954895
# low resolution, adversarial loss at step 13400: 2.1315827
# --- 19.250147581100464 seconds ---
# level_0
# low resolution, discriminator loss at step 13500: 0.32384127378463745
# low resolution, adversarial loss at step 13500: 2.9890027
# --- 19.01746964454651 seconds ---
# level_0
# low resolution, discriminator loss at step 13600: 0.8575891256332397
# low resolution, adversarial loss at step 13600: 2.6694021
# --- 18.766318798065186 seconds ---
# level_0
# low resolution, discriminator loss at step 13700: 0.46061283349990845
# low resolution, adversarial loss at step 13700: 1.9522779
# --- 18.898756742477417 seconds ---
# level_0
# low resolution, discriminator loss at step 13800: 0.516167402267456
# low resolution, adversarial loss at step 13800: 2.162004
# --- 18.775409936904907 seconds ---
# level_0
# low resolution, discriminator loss at step 13900: 0.6039583683013916
# low resolution, adversarial loss at step 13900: 2.357312
# --- 19.146938800811768 seconds ---
# level_0
# low resolution, discriminator loss at step 14000: 0.5336695313453674
# low resolution, adversarial loss at step 14000: 1.6042373
# --- 18.730151653289795 seconds ---
# level_0
# low resolution, discriminator loss at step 14100: 0.4967171847820282
# low resolution, adversarial loss at step 14100: 2.06205
# --- 19.44616413116455 seconds ---
# level_0
# low resolution, discriminator loss at step 14200: 0.3702583312988281
# low resolution, adversarial loss at step 14200: 2.630676
# --- 18.722578287124634 seconds ---
# level_0
# low resolution, discriminator loss at step 13800: 0.48042285442352295
# low resolution, adversarial loss at step 13800: 2.3430314
# --- 8.881487846374512 seconds ---
# level_0
# low resolution, discriminator loss at step 13900: 0.5165968537330627
# low resolution, adversarial loss at step 13900: 2.4168668
# --- 18.898999214172363 seconds ---
# level_0
# low resolution, discriminator loss at step 14000: 0.3703992962837219
# low resolution, adversarial loss at step 14000: 1.9060411
# --- 18.749372959136963 seconds ---
# level_0
# low resolution, discriminator loss at step 14100: 0.4548577070236206
# low resolution, adversarial loss at step 14100: 2.0818563
# --- 19.038424491882324 seconds ---
# level_0
# low resolution, discriminator loss at step 14200: 0.4230778217315674
# low resolution, adversarial loss at step 14200: 2.0110226
# --- 19.119967460632324 seconds ---
# level_0
# low resolution, discriminator loss at step 14300: 0.3131050169467926
# low resolution, adversarial loss at step 14300: 2.7653184
# --- 18.88349485397339 seconds ---
# level_0
# low resolution, discriminator loss at step 14400: 0.7894424796104431
# low resolution, adversarial loss at step 14400: 3.08094
# --- 18.91094422340393 seconds ---
# level_0
# low resolution, discriminator loss at step 14500: 0.4160892367362976
# low resolution, adversarial loss at step 14500: 2.469767
# --- 18.96748971939087 seconds ---
# level_0
# low resolution, discriminator loss at step 14600: 0.3984757661819458
# low resolution, adversarial loss at step 14600: 2.7929783
# --- 19.137474060058594 seconds ---
# level_0
# low resolution, discriminator loss at step 14700: 0.6693207025527954
# low resolution, adversarial loss at step 14700: 2.2183585
# --- 19.015478134155273 seconds ---
# level_0
# low resolution, discriminator loss at step 14800: 0.5081378817558289
# low resolution, adversarial loss at step 14800: 1.877014
# --- 19.01029634475708 seconds ---
# level_0
# low resolution, discriminator loss at step 14400: 0.7638053894042969
# low resolution, adversarial loss at step 14400: 2.2815032
# --- 8.736139059066772 seconds ---
# level_0
# low resolution, discriminator loss at step 14500: 0.3070434033870697
# low resolution, adversarial loss at step 14500: 1.6223614
# --- 18.994279146194458 seconds ---
# level_0
# low resolution, discriminator loss at step 14600: 0.3292851448059082
# low resolution, adversarial loss at step 14600: 2.151704
# --- 18.706756353378296 seconds ---
# level_0
# low resolution, discriminator loss at step 14700: 0.5129938125610352
# low resolution, adversarial loss at step 14700: 1.5118486
# --- 19.348702430725098 seconds ---
# level_0
# low resolution, discriminator loss at step 14800: 0.41484177112579346
# low resolution, adversarial loss at step 14800: 2.4940047
# --- 18.742615699768066 seconds ---
# level_0
# low resolution, discriminator loss at step 14900: 0.3885979652404785
# low resolution, adversarial loss at step 14900: 2.3675818
# --- 20.578532218933105 seconds ---
# level_0
# low resolution, discriminator loss at step 15000: 0.34316644072532654
# low resolution, adversarial loss at step 15000: 2.9002306
# --- 18.50259304046631 seconds ---
# level_0
# low resolution, discriminator loss at step 15100: 0.4757808446884155
# low resolution, adversarial loss at step 15100: 1.9191737
# --- 18.892356157302856 seconds ---
# level_0
# low resolution, discriminator loss at step 15200: 0.5077580809593201
# low resolution, adversarial loss at step 15200: 1.7836887
# --- 18.919426441192627 seconds ---
# level_0
# low resolution, discriminator loss at step 15300: 0.39828163385391235
# low resolution, adversarial loss at step 15300: 2.566389
# --- 18.638689279556274 seconds ---
# level_0
# low resolution, discriminator loss at step 15400: 0.5469225645065308
# low resolution, adversarial loss at step 15400: 2.097769
# --- 19.00083017349243 seconds ---
# level_0
# low resolution, discriminator loss at step 15000: 0.6309587955474854
# low resolution, adversarial loss at step 15000: 1.2920532
# --- 8.809046030044556 seconds ---
# level_0
# low resolution, discriminator loss at step 15100: 0.3629891872406006
# low resolution, adversarial loss at step 15100: 2.7967691
# --- 18.939990997314453 seconds ---
# level_0
# low resolution, discriminator loss at step 15200: 0.38493621349334717
# low resolution, adversarial loss at step 15200: 1.9963821
# --- 19.000725507736206 seconds ---
# level_0
# low resolution, discriminator loss at step 15300: 0.41136622428894043
# low resolution, adversarial loss at step 15300: 2.1638417
# --- 18.78572416305542 seconds ---
# level_0
# low resolution, discriminator loss at step 15400: 0.6952707767486572
# low resolution, adversarial loss at step 15400: 1.9595475
# --- 18.907967805862427 seconds ---
# level_0
# low resolution, discriminator loss at step 15500: 0.5745168328285217
# low resolution, adversarial loss at step 15500: 2.5888329
# --- 18.83005380630493 seconds ---
# level_0
# low resolution, discriminator loss at step 15600: 0.5890929698944092
# low resolution, adversarial loss at step 15600: 2.0720067
# --- 26.64171814918518 seconds ---
# level_0
# low resolution, discriminator loss at step 15700: 0.4133495092391968
# low resolution, adversarial loss at step 15700: 2.0296602
# --- 32.49007225036621 seconds ---
# level_0
# low resolution, discriminator loss at step 15800: 0.45496487617492676
# low resolution, adversarial loss at step 15800: 2.5612211
# --- 29.28329849243164 seconds ---
# level_0
# low resolution, discriminator loss at step 15900: 0.4187019467353821
# low resolution, adversarial loss at step 15900: 2.5298963
# --- 26.012781381607056 seconds ---
# level_0
# low resolution, discriminator loss at step 16000: 0.5536125898361206
# low resolution, adversarial loss at step 16000: 2.5182576
# --- 25.564688444137573 seconds ---
# level_0
# low resolution, discriminator loss at step 15600: 0.40771985054016113
# low resolution, adversarial loss at step 15600: 1.6185404
# --- 20.979318618774414 seconds ---
# level_0
# low resolution, discriminator loss at step 15700: 0.5415401458740234
# ...
# --- 19.105565786361694 seconds ---
# level_0
# low resolution, discriminator loss at step 57200: 0.539827823638916
# low resolution, adversarial loss at step 57200: 4.01348
# --- 18.61311984062195 seconds ---
# level_0
# low resolution, discriminator loss at step 57300: 0.3280732035636902
# low resolution, adversarial loss at step 57300: 3.235342
# --- 18.474117755889893 seconds ---
# level_0
# low resolution, discriminator loss at step 57400: 0.4705495834350586
# low resolution, adversarial loss at step 57400: 2.0000036
# --- 18.639121770858765 seconds ---
# level_0
# low resolution, discriminator loss at step 57000: 0.3379487097263336
# low resolution, adversarial loss at step 57000: 2.2279208
# --- 8.917907238006592 seconds ---
# level_0
# low resolution, discriminator loss at step 57100: 0.3418014347553253
# low resolution, adversarial loss at step 57100: 2.9576988
# --- 18.622395992279053 seconds ---
# level_0
# low resolution, discriminator loss at step 57200: 0.3177322447299957
# low resolution, adversarial loss at step 57200: 3.261007
# --- 18.850141763687134 seconds ---
# level_0
# low resolution, discriminator loss at step 57300: 0.2510901987552643
# low resolution, adversarial loss at step 57300: 3.244745
# --- 18.77496838569641 seconds ---
# level_0
# low resolution, discriminator loss at step 57400: 0.26876142621040344
# low resolution, adversarial loss at step 57400: 3.4833755
# --- 18.588265419006348 seconds ---
# level_0
# low resolution, discriminator loss at step 57500: 0.2896976172924042
# low resolution, adversarial loss at step 57500: 2.4467714
# --- 18.689664363861084 seconds ---
# level_0
# low resolution, discriminator loss at step 57600: 0.2516864538192749
# low resolution, adversarial loss at step 57600: 4.071725
# --- 18.837254762649536 seconds ---
# level_0
# low resolution, discriminator loss at step 57700: 0.4111442267894745
# low resolution, adversarial loss at step 57700: 3.3727193
# --- 18.72722363471985 seconds ---
# level_0
# low resolution, discriminator loss at step 57800: 0.37143000960350037
# low resolution, adversarial loss at step 57800: 3.6195717
# --- 18.602116346359253 seconds ---
# level_0
# low resolution, discriminator loss at step 57900: 0.2538786232471466
# low resolution, adversarial loss at step 57900: 2.628768
# --- 18.670593738555908 seconds ---
# level_0
# low resolution, discriminator loss at step 58000: 0.26727595925331116
# low resolution, adversarial loss at step 58000: 3.6048193
# --- 18.779096841812134 seconds ---
# level_0
# low resolution, discriminator loss at step 57600: 0.44220152497291565
# low resolution, adversarial loss at step 57600: 4.3877983
# --- 8.528099536895752 seconds ---
# level_0
# low resolution, discriminator loss at step 57700: 0.24765698611736298
# low resolution, adversarial loss at step 57700: 3.6133199
# --- 19.000967979431152 seconds ---
# level_0
# low resolution, discriminator loss at step 57800: 0.2700537443161011
# low resolution, adversarial loss at step 57800: 3.62896
# --- 19.05060338973999 seconds ---
# level_0
# low resolution, discriminator loss at step 57900: 0.2817533016204834
# low resolution, adversarial loss at step 57900: 3.696249
# --- 18.8652925491333 seconds ---
# level_0
# low resolution, discriminator loss at step 58000: 0.2591680884361267
# low resolution, adversarial loss at step 58000: 3.6658566
# --- 20.214017868041992 seconds ---
# level_0
# low resolution, discriminator loss at step 58100: 0.23773938417434692
# low resolution, adversarial loss at step 58100: 3.1792727
# --- 18.65735650062561 seconds ---
# level_0
# low resolution, discriminator loss at step 58200: 0.20995765924453735
# low resolution, adversarial loss at step 58200: 4.588434
# --- 18.614274501800537 seconds ---
# level_0
# low resolution, discriminator loss at step 58300: 0.2495587319135666
# low resolution, adversarial loss at step 58300: 3.1821966
# --- 18.775495052337646 seconds ---
# level_0
# low resolution, discriminator loss at step 58400: 0.3590836822986603
# low resolution, adversarial loss at step 58400: 3.3059828
# --- 18.76505398750305 seconds ---
# level_0
# low resolution, discriminator loss at step 58500: 0.20045356452465057
# low resolution, adversarial loss at step 58500: 3.8070517
# --- 18.647533416748047 seconds ---
# level_0
# low resolution, discriminator loss at step 58600: 0.34092798829078674
# low resolution, adversarial loss at step 58600: 3.5741673
# --- 20.482346534729004 seconds ---
# level_0
# low resolution, discriminator loss at step 58200: 0.340663880109787
# low resolution, adversarial loss at step 58200: 4.8958173
# --- 8.816301584243774 seconds ---
# level_0
# low resolution, discriminator loss at step 58300: 0.37526577711105347
# low resolution, adversarial loss at step 58300: 3.290582
# --- 18.83009362220764 seconds ---
# level_0
# low resolution, discriminator loss at step 58400: 0.30374449491500854
# low resolution, adversarial loss at step 58400: 2.61702
# --- 18.952163219451904 seconds ---
# level_0
# low resolution, discriminator loss at step 58500: 0.3175402283668518
# low resolution, adversarial loss at step 58500: 4.5369434
# --- 18.756607055664062 seconds ---
# level_0
# low resolution, discriminator loss at step 58600: 0.33006975054740906
# low resolution, adversarial loss at step 58600: 3.4005854
# --- 18.6160671710968 seconds ---
# level_0
# low resolution, discriminator loss at step 58700: 0.36119747161865234
# low resolution, adversarial loss at step 58700: 2.3023915
# --- 18.745211362838745 seconds ---
# level_0
# low resolution, discriminator loss at step 58800: 0.3417457938194275
# low resolution, adversarial loss at step 58800: 2.4283028
# --- 28.163285970687866 seconds ---
# level_0
# low resolution, discriminator loss at step 58900: 0.2901571989059448
# low resolution, adversarial loss at step 58900: 2.6921
# --- 32.059876441955566 seconds ---
# level_0
# low resolution, discriminator loss at step 59000: 0.2845083177089691
# low resolution, adversarial loss at step 59000: 3.37614
# --- 31.286327838897705 seconds ---
# level_0
# low resolution, discriminator loss at step 59100: 0.3813101053237915
# low resolution, adversarial loss at step 59100: 3.664038
# --- 23.91713571548462 seconds ---
# level_0
# low resolution, discriminator loss at step 59200: 0.29480957984924316
# low resolution, adversarial loss at step 59200: 2.8645334
# --- 24.354501247406006 seconds ---
# level_0
# low resolution, discriminator loss at step 58800: 0.2938259541988373
# low resolution, adversarial loss at step 58800: 4.786072
# --- 15.447600603103638 seconds ---
# level_0
# low resolution, discriminator loss at step 58900: 0.3294168710708618
# low resolution, adversarial loss at step 58900: 4.082202
# --- 23.046329498291016 seconds ---
# level_0
# low resolution, discriminator loss at step 59000: 0.8070917129516602
# low resolution, adversarial loss at step 59000: 6.143578
# --- 25.262736558914185 seconds ---
# level_0
# low resolution, discriminator loss at step 59100: 0.22908461093902588
# low resolution, adversarial loss at step 59100: 2.7800958
# --- 27.42205786705017 seconds ---
# level_0
# low resolution, discriminator loss at step 59200: 0.29763728380203247
# low resolution, adversarial loss at step 59200: 3.46773
# --- 26.9920916557312 seconds ---
# level_0
# low resolution, discriminator loss at step 59300: 0.3187509775161743
# low resolution, adversarial loss at step 59300: 3.8972552
# --- 18.947343587875366 seconds ---
# level_0
# low resolution, discriminator loss at step 59400: 0.28404414653778076
# low resolution, adversarial loss at step 59400: 2.746776
# --- 19.081289052963257 seconds ---
# level_0
# low resolution, discriminator loss at step 59500: 0.3300407826900482
# low resolution, adversarial loss at step 59500: 3.6465783
# --- 18.77606773376465 seconds ---
# level_0
# low resolution, discriminator loss at step 59600: 0.24057306349277496
# low resolution, adversarial loss at step 59600: 4.3232417
# --- 18.774019956588745 seconds ---
# level_0
# low resolution, discriminator loss at step 59700: 0.3275553286075592
# low resolution, adversarial loss at step 59700: 3.5337605
# --- 18.533809661865234 seconds ---
# level_0
# low resolution, discriminator loss at step 59800: 0.32498061656951904
# low resolution, adversarial loss at step 59800: 3.4302187
# --- 18.85237693786621 seconds ---
# level_0
# low resolution, discriminator loss at step 59400: 0.30638933181762695
# low resolution, adversarial loss at step 59400: 3.8149264
# --- 9.085077285766602 seconds ---
# level_0
# low resolution, discriminator loss at step 59500: 0.28842049837112427
# low resolution, adversarial loss at step 59500: 3.2551398
# --- 19.08703875541687 seconds ---
# level_0
# low resolution, discriminator loss at step 59600: 0.43785983324050903
# low resolution, adversarial loss at step 59600: 3.4668467
# --- 18.673888206481934 seconds ---
# level_0
# low resolution, discriminator loss at step 59700: 0.36018168926239014
# low resolution, adversarial loss at step 59700: 4.0571404
# --- 18.908308506011963 seconds ---
# level_0
# low resolution, discriminator loss at step 59800: 0.25762173533439636
# low resolution, adversarial loss at step 59800: 3.1543806
# --- 18.734442710876465 seconds ---
# level_0
# low resolution, discriminator loss at step 59900: 0.3362778425216675
# low resolution, adversarial loss at step 59900: 3.8586268
# --- 18.652671813964844 seconds ---
# level_0
# low resolution, discriminator loss at step 60000: 0.31356775760650635
# low resolution, adversarial loss at step 60000: 3.6013396
# --- 18.700966358184814 seconds ---
# level_0
# low resolution, discriminator loss at step 60100: 0.39269110560417175
# low resolution, adversarial loss at step 60100: 3.4292378
# --- 18.603676795959473 seconds ---
# level_0
# low resolution, discriminator loss at step 60200: 0.33752164244651794
# low resolution, adversarial loss at step 60200: 3.5436988
# --- 18.633906602859497 seconds ---
# level_0
# low resolution, discriminator loss at step 60300: 0.22426635026931763
# low resolution, adversarial loss at step 60300: 3.1098275
# --- 18.616288661956787 seconds ---
# level_0
# low resolution, discriminator loss at step 60400: 0.2505566477775574
# low resolution, adversarial loss at step 60400: 3.2896285
# --- 18.6635525226593 seconds ---
# level_0
# low resolution, discriminator loss at step 60000: 0.29670533537864685
# low resolution, adversarial loss at step 60000: 3.896118
# --- 8.77890396118164 seconds ---
# level_0
# low resolution, discriminator loss at step 60100: 0.3135499060153961
# low resolution, adversarial loss at step 60100: 3.9781528
# --- 18.562605619430542 seconds ---
# level_0
# low resolution, discriminator loss at step 60200: 0.31661197543144226
# low resolution, adversarial loss at step 60200: 4.9797072
# --- 18.417126893997192 seconds ---
# level_0
# low resolution, discriminator loss at step 60300: 0.23601970076560974
# low resolution, adversarial loss at step 60300: 2.9681373
# --- 19.034614086151123 seconds ---
# level_0
# low resolution, discriminator loss at step 60400: 0.3277113437652588
# low resolution, adversarial loss at step 60400: 3.773896
# --- 18.465508460998535 seconds ---
# level_0
# low resolution, discriminator loss at step 60500: 0.32244357466697693
# low resolution, adversarial loss at step 60500: 3.8604708
# --- 20.565305471420288 seconds ---
# level_0
# low resolution, discriminator loss at step 60600: 0.2698266804218292
# low resolution, adversarial loss at step 60600: 3.0486825
# --- 18.475238800048828 seconds ---
# level_0
# low resolution, discriminator loss at step 60700: 0.4044588506221771
# low resolution, adversarial loss at step 60700: 4.059911
# --- 19.013028383255005 seconds ---
# level_0
# low resolution, discriminator loss at step 60800: 0.25537002086639404
# low resolution, adversarial loss at step 60800: 2.5829234
# --- 18.88619303703308 seconds ---
# level_0
# low resolution, discriminator loss at step 60900: 0.2904960513114929
# low resolution, adversarial loss at step 60900: 2.9273407
# --- 18.658293962478638 seconds ---
# level_0
# low resolution, discriminator loss at step 61000: 0.37736523151397705
# low resolution, adversarial loss at step 61000: 3.8856905
# --- 18.476626873016357 seconds ---
# level_0
# low resolution, discriminator loss at step 60600: 0.2908934950828552
# low resolution, adversarial loss at step 60600: 3.5704176
# --- 8.588902235031128 seconds ---
# level_0
# low resolution, discriminator loss at step 60700: 0.26193881034851074
# low resolution, adversarial loss at step 60700: 3.7255871
# --- 18.46737790107727 seconds ---
# level_0
# low resolution, discriminator loss at step 60800: 0.30910634994506836
# low resolution, adversarial loss at step 60800: 3.3247929
# --- 18.723975658416748 seconds ---
# level_0
# low resolution, discriminator loss at step 60900: 0.3456505239009857
# low resolution, adversarial loss at step 60900: 4.5379276
# --- 18.824449062347412 seconds ---
# level_0
# low resolution, discriminator loss at step 61000: 0.2587487995624542
# low resolution, adversarial loss at step 61000: 5.014882
# --- 18.571240663528442 seconds ---
# level_0
# low resolution, discriminator loss at step 61100: 0.24869272112846375
# low resolution, adversarial loss at step 61100: 4.0692816
# --- 18.65092182159424 seconds ---
# level_0
# low resolution, discriminator loss at step 61200: 0.23479969799518585
# low resolution, adversarial loss at step 61200: 3.3671422
# --- 18.82319188117981 seconds ---
# level_0
# low resolution, discriminator loss at step 61300: 0.25403931736946106
# low resolution, adversarial loss at step 61300: 3.2066112
# --- 18.820117473602295 seconds ---
# level_0
# low resolution, discriminator loss at step 61400: 0.2417251169681549
# low resolution, adversarial loss at step 61400: 2.3571959
# --- 18.668975114822388 seconds ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-d8bddd58bf28> in <module>
#      74             misleading_targets = np.ones((batch_size, 1))
#      75
# ---> 76             g_loss = GAN1.train_on_batch(random_latent_vectors, misleading_targets)
#      77
#      78
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1254       if reset_metrics:
#    1255         self._make_train_function()
# -> 1256         outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1257       else:
#    1258         self._make_fit_function()
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3215         value = math_ops.cast(value, tensor.dtype)
#    3216       converted_inputs.append(value)
# -> 3217     outputs = self._graph_fn(*converted_inputs)
#    3218     return nest.pack_sequence_as(self._outputs_structure,
#    3219                                  [x.numpy() for x in outputs])
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#     556       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#     557           list(kwargs.keys()), list(self._arg_keywords)))
# --> 558     return self._call_flat(args)
#     559
#     560   def _filtered_call(self, args, kwargs):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args)
#     625     # Only need to override the gradient in graph mode and when we have outputs.
#     626     if context.executing_eagerly() or not self.outputs:
# --> 627       outputs = self._inference_function.call(ctx, args)
#     628     else:
#     629       self._register_gradient()
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args)
#     413             attrs=("executor_type", executor_type,
#     414                    "config_proto", config),
# --> 415             ctx=ctx)
#     416       # Replace empty list with None
#     417       outputs = outputs or None
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      59                                                op_name, inputs, attrs,
# ---> 60                                                num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# G.get_layer(G.layers[5]._name)`

# %%
# G.layers[5]._name
